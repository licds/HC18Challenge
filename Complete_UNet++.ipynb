# %% [markdown]
# # Libraries Import

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] ="0,1,2,3"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from skimage import io, color #Scikit-Image
from PIL import Image # Pillow
import cv2
import pickle

import os
import random

import torch # Will work on using PyTorch here later
from torch.utils.data  import Dataset, DataLoader
from torchvision import transforms
import torchvision.transforms.functional as TF
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from google.colab import drive
print(torch.__version__)
# Out:
# 1.13.0+cu116

# %% [markdown]
# # Create Datasets

# %%
class HC18(Dataset):
    def __init__(self, train = True, transformX = None, transformY = None):
        self.pixel_file = pd.read_csv('training_set_pixel_size_and_HC.csv')
        self.transformX = transformX
        self.transformY = transformY
        self.train = train
        
        # Split the dataset to train and validation using sklearn function train_test_split
        self.train_data, self.validation_data = train_test_split(self.pixel_file, 
                                                                 test_size = validation_set_size, 
                                                                 random_state = 5)

    def __len__(self):
        if self.train:
            return len(self.train_data)
        return len(self.validation_data)
    
    def __getitem__(self, index):
        if self.train:
            imx_name = os.path.join('training_set', 
                                  self.train_data.iloc[index, 0])
            imy_name = os.path.join('training_set',
                                  self.train_data.iloc[index, 0].replace('.png','_Annotation.png'))
        else:
            imx_name = os.path.join('training_set', 
                                  self.validation_data.iloc[index, 0])
            imy_name = os.path.join('training_set',
                                  self.validation_data.iloc[index, 0].replace('.png','_Annotation.png'))
        imx = Image.open(imx_name)
        # Changing the image to greyscale, visit https://pillow.readthedocs.io/en/stable/reference/Image.html
        imy = Image.open(imy_name).convert('L')
        
        # We can try to not use these later, as of now, just follow what the author has
        ## tried some data augmentation techniques
        if self.train:
          # Random horizontal flipping
          if random.random() > 0.5:
              imx = TF.hflip(imx)
              imy = TF.hflip(imy)

          # Random vertical flipping
          if random.random() > 0.5:
              imx = TF.vflip(imx)
              imy = TF.vflip(imy)

          # Random rotation
          if random.random() > 0.8:
            angle = random.choice([-30, -90, -60, -45 -15, 0, 15, 30, 45, 60, 90])
            imx = TF.rotate(imx, angle)
            imy = TF.rotate(imy, angle)
        
        # We will use resize, tensorlize, and normalize in the following cell
        if self.transformX :
            imx = self.transformX(imx)
            imy = self.transformY(imy)
        
        sample = {'image': imx, 'annotation': imy}
        return sample

# %%
drive.mount('/content/gdrive')
parent_folder = '/content/gdrive/MyDrive/HC18'
data_folder = '/content/gdrive/MyDrive/HC18/data'


with open(os.path.join(parent_folder, 'train_data.pickle'), 'rb') as f:
    train_data = pickle.load(f)
with open(os.path.join(parent_folder, 'validation_data.pickle'), 'rb') as f:
    validation_data = pickle.load(f)

# Dataloaders
train_loader = DataLoader(dataset = train_data, batch_size = 2)
validation_loader = DataLoader(dataset = validation_data, batch_size = 2)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Build the Model

# %% [markdown]
# # Unet++

# %%
from torch.nn import init

def weights_init_normal(m):
    classname = m.__class__.__name__
    #print(classname)
    if classname.find('Conv') != -1:
        init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('Linear') != -1:
        init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        init.normal_(m.weight.data, 1.0, 0.02)
        init.constant_(m.bias.data, 0.0)


def weights_init_xavier(m):
    classname = m.__class__.__name__
    #print(classname)
    if classname.find('Conv') != -1:
        init.xavier_normal_(m.weight.data, gain=1)
    elif classname.find('Linear') != -1:
        init.xavier_normal_(m.weight.data, gain=1)
    elif classname.find('BatchNorm') != -1:
        init.normal_(m.weight.data, 1.0, 0.02)
        init.constant_(m.bias.data, 0.0)


def weights_init_kaiming(m):
    classname = m.__class__.__name__
    #print(classname)
    if classname.find('Conv') != -1:
        init.kaiming_normal_(m.weight.data, a=0, mode='fan_in')
    elif classname.find('Linear') != -1:
        init.kaiming_normal_(m.weight.data, a=0, mode='fan_in')
    elif classname.find('BatchNorm') != -1:
        init.normal_(m.weight.data, 1.0, 0.02)
        init.constant_(m.bias.data, 0.0)


def weights_init_orthogonal(m):
    classname = m.__class__.__name__
    #print(classname)
    if classname.find('Conv') != -1:
        init.orthogonal_(m.weight.data, gain=1)
    elif classname.find('Linear') != -1:
        init.orthogonal_(m.weight.data, gain=1)
    elif classname.find('BatchNorm') != -1:
        init.normal_(m.weight.data, 1.0, 0.02)
        init.constant_(m.bias.data, 0.0)


def init_weights(net, init_type='normal'):
    #print('initialization method [%s]' % init_type)
    if init_type == 'normal':
        net.apply(weights_init_normal)
    elif init_type == 'xavier':
        net.apply(weights_init_xavier)
    elif init_type == 'kaiming':
        net.apply(weights_init_kaiming)
    elif init_type == 'orthogonal':
        net.apply(weights_init_orthogonal)
    else:
        raise NotImplementedError('initialization method [%s] is not implemented' % init_type)

# %%
class unetConv2(nn.Module):
    def __init__(self, in_size, out_size, is_batchnorm, n=2, ks=3, stride=1, padding=1):
        super(unetConv2, self).__init__()
        self.n = n
        self.ks = ks
        self.stride = stride
        self.padding = padding
        s = stride
        p = padding
        
        if is_batchnorm:
            for i in range(1, n + 1):
                conv = nn.Sequential(nn.Conv2d(in_size, out_size, ks, s, p),
                                     nn.BatchNorm2d(out_size),
                                     nn.ReLU(inplace=True), )
                setattr(self, 'conv%d' % i, conv)
                in_size = out_size

        else:
            for i in range(1, n + 1):
                conv = nn.Sequential(nn.Conv2d(in_size, out_size, ks, s, p),
                                     nn.ReLU(inplace=True), )
                setattr(self, 'conv%d' % i, conv)
                in_size = out_size

        # initialise the blocks
        for m in self.children():
            init_weights(m, init_type='kaiming')

    def forward(self, inputs):
        x = inputs
        for i in range(1, self.n + 1):
            conv = getattr(self, 'conv%d' % i)
            x = conv(x)

        return x

class unetUp(nn.Module):
    def __init__(self, in_size, out_size, is_deconv, n_concat=2):
        super(unetUp, self).__init__()
        # self.conv = unetConv2(in_size + (n_concat - 2) * out_size, out_size, False)
        self.conv = unetConv2(out_size*2, out_size, False)
        if is_deconv:
            self.up = nn.ConvTranspose2d(in_size, out_size, kernel_size=4, stride=2, padding=1)
        else:
            self.up = nn.UpsamplingBilinear2d(scale_factor=2)

        # initialise the blocks
        for m in self.children():
            if m.__class__.__name__.find('unetConv2') != -1: continue
            init_weights(m, init_type='kaiming')

    def forward(self, inputs0, *input):
        # print(self.n_concat)
        # print(input)
        outputs0 = self.up(inputs0)
        for i in range(len(input)):
            outputs0 = torch.cat([outputs0, input[i]], 1)
        return self.conv(outputs0)
    
class unetUp_origin(nn.Module):
    def __init__(self, in_size, out_size, is_deconv, n_concat=2):
        super(unetUp_origin, self).__init__()
        # self.conv = unetConv2(out_size*2, out_size, False)
        if is_deconv:
            self.conv = unetConv2(in_size + (n_concat - 2) * out_size, out_size, False)
            self.up = nn.ConvTranspose2d(in_size, out_size, kernel_size=2, stride=2)
        else:
            self.conv = unetConv2(in_size + (n_concat - 2) * out_size, out_size, False)
            self.up = nn.UpsamplingBilinear2d(scale_factor=2)

        # initialise the blocks
        for m in self.children():
            if m.__class__.__name__.find('unetConv2') != -1: continue
            init_weights(m, init_type='kaiming')

    def forward(self, inputs0, *input):
        x1 = self.up(inputs0)
        # input is CHW
        for i in range(len(input)):
            try:
                x1 = torch.cat((x1,input[i]),1)
            except:
                x1 = torch.cat((F.pad(x1,(1,0,1,0)),input[i]),1)
        return self.conv(x1)

# %%
class UNet_2Plus(nn.Module):
    def __init__(self, in_channels=1, n_classes=1, feature_scale=4, is_deconv=True, is_batchnorm=True, is_ds=True):
        super(UNet_2Plus, self).__init__()
        self.is_deconv = is_deconv
        self.in_channels = in_channels
        self.is_batchnorm = is_batchnorm
        self.is_ds = is_ds
        self.feature_scale = feature_scale

        filters = [64, 128, 256, 512, 1024]

        # downsampling
        self.conv00 = unetConv2(self.in_channels, filters[0], self.is_batchnorm)
        self.maxpool0 = nn.MaxPool2d(kernel_size=2)
        self.conv10 = unetConv2(filters[0], filters[1], self.is_batchnorm)
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        self.conv20 = unetConv2(filters[1], filters[2], self.is_batchnorm)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        self.conv30 = unetConv2(filters[2], filters[3], self.is_batchnorm)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)
        self.conv40 = unetConv2(filters[3], filters[4], self.is_batchnorm)


        # upsampling
        self.up_concat01 = unetUp_origin(filters[1], filters[0], self.is_deconv)
        self.up_concat11 = unetUp_origin(filters[2], filters[1], self.is_deconv)
        self.up_concat21 = unetUp_origin(filters[3], filters[2], self.is_deconv)
        self.up_concat31 = unetUp_origin(filters[4], filters[3], self.is_deconv)

        self.up_concat02 = unetUp_origin(filters[1], filters[0], self.is_deconv, 3)
        self.up_concat12 = unetUp_origin(filters[2], filters[1], self.is_deconv, 3)
        self.up_concat22 = unetUp_origin(filters[3], filters[2], self.is_deconv, 3)

        self.up_concat03 = unetUp_origin(filters[1], filters[0], self.is_deconv, 4)
        self.up_concat13 = unetUp_origin(filters[2], filters[1], self.is_deconv, 4)

        self.up_concat04 = unetUp_origin(filters[1], filters[0], self.is_deconv, 5)

        # final conv (without any concat)
        self.final_1 = nn.Conv2d(filters[0], n_classes, 1)
        self.final_2 = nn.Conv2d(filters[0], n_classes, 1)
        self.final_3 = nn.Conv2d(filters[0], n_classes, 1)
        self.final_4 = nn.Conv2d(filters[0], n_classes, 1)

        # initialise weights
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                init_weights(m, init_type='kaiming')
            elif isinstance(m, nn.BatchNorm2d):
                init_weights(m, init_type='kaiming')

    def forward(self, inputs):
        # column : 0
        X_00 = self.conv00(inputs)
        maxpool0 = self.maxpool0(X_00)
        X_10 = self.conv10(maxpool0)
        maxpool1 = self.maxpool1(X_10)
        X_20 = self.conv20(maxpool1)
        maxpool2 = self.maxpool2(X_20)
        X_30 = self.conv30(maxpool2)
        maxpool3 = self.maxpool3(X_30)
        X_40 = self.conv40(maxpool3)

        # column : 1
        X_01 = self.up_concat01(X_10, X_00)
        X_11 = self.up_concat11(X_20, X_10)
        X_21 = self.up_concat21(X_30, X_20)
        X_31 = self.up_concat31(X_40, X_30)
        # column : 2
        X_02 = self.up_concat02(X_11, X_00, X_01)
        X_12 = self.up_concat12(X_21, X_10, X_11)
        X_22 = self.up_concat22(X_31, X_20, X_21)
        # column : 3
        X_03 = self.up_concat03(X_12, X_00, X_01, X_02)
        X_13 = self.up_concat13(X_22, X_10, X_11, X_12)
        # column : 4
        X_04 = self.up_concat04(X_13, X_00, X_01, X_02, X_03)

        # final layer
        final_1 = self.final_1(X_01)
        final_2 = self.final_2(X_02)
        final_3 = self.final_3(X_03)
        final_4 = self.final_4(X_04)

        final = (final_1 + final_2 + final_3 + final_4) / 4

        if self.is_ds:
            return F.sigmoid(final)
        else:
            return F.sigmoid(final_4)

# %%
model = UNet_2Plus()
model.to('cuda')
print("Model Loaded to GPU")
# Out:
# Model Loaded to GPU

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)

# %%
# calculates similarity index between predicted and actual segmentation
def dice_index(y_pred, y_actual):
    smooth = 0.000001
    size_of_batch = y_pred.size(0)
    
    p1 = y_pred.view(size_of_batch, -1)
    p2 = y_actual.view(size_of_batch, -1)
    
    intersection = (p1 * p2).sum()
    
    dice =  ((2.0 * intersection )+ smooth) / (p1.sum() + p2.sum() + smooth)
    #dice.requires_grad = True
    
    return dice

# calculate dice loss which will be later used in loss function calculation
def dice_loss(y_predict, y_train): ## to add in bce looss
    return 1 -(dice_index(y_predict, y_train))

# %%
epochs = 20 

train_running_loss_history = []
validation_running_loss_history =[]

for e in range(epochs):
    train_running_loss = 0.0
    validation_running_loss = 0.0  
    model.train()
    for ith_batch, sample_batched in enumerate(train_loader):
        X_train = sample_batched['image'].to("cuda")
        y_train = sample_batched['annotation'].to("cuda")
        optimizer.zero_grad()
        y_pred = model(X_train)
        loss = 0.30 * dice_loss(y_pred, y_train) +  0.70 * criterion(y_pred, y_train)
        loss.backward()
        optimizer.step()
        if ith_batch % 50 == 0:
            print('Epoch: ', e + 1, 'Batch: ', ith_batch, 'Current Loss: ', loss.item())
        train_running_loss += loss.item()
    else:
        with torch.no_grad():
            model.eval()
            for ith_batch, sample_batched in enumerate(validation_loader):
                X_val = sample_batched['image'].to("cuda")
                y_val = sample_batched['annotation'].to("cuda")
                y_out = model(X_val)
                out_val = (y_out + 0.5).int().float()
                val_loss = 0.3 * dice_loss(out_val, y_val)  + 0.7 * criterion(y_out, y_val)
                validation_running_loss += val_loss.item()
            print("================================================================================")
            print("Epoch {} completed".format(e + 1))

            train_epoch_loss = train_running_loss / len(train_loader)
            validation_epoch_loss = validation_running_loss / len(validation_loader)

            print("Average train loss is {}: ".format(train_epoch_loss))
            print("Average validation loss is {}".format(validation_epoch_loss))
            print("================================================================================")
            train_running_loss_history.append(train_epoch_loss)
            validation_running_loss_history.append(validation_epoch_loss)

    torch.cuda.empty_cache()
# Out:
# /mmfs1/data/licds/.local/lib/python3.9/site-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch:  1 Batch:  0 Current Loss:  0.6849687099456787
# Epoch:  1 Batch:  50 Current Loss:  0.4218757748603821
# Epoch:  1 Batch:  100 Current Loss:  0.2937900424003601
# Epoch:  1 Batch:  150 Current Loss:  0.41865459084510803
# Epoch:  1 Batch:  200 Current Loss:  0.29288041591644287
# Epoch:  1 Batch:  250 Current Loss:  0.23436874151229858
# Epoch:  1 Batch:  300 Current Loss:  0.20493990182876587
# Epoch:  1 Batch:  350 Current Loss:  0.17475487291812897
# ================================================================================
# Epoch 1 completed
# Average train loss is 0.31955666963011026:
# Average validation loss is 0.23209361523389815
# ================================================================================
# Epoch:  2 Batch:  0 Current Loss:  0.3636965751647949
# Epoch:  2 Batch:  50 Current Loss:  0.35569965839385986
# Epoch:  2 Batch:  100 Current Loss:  0.13151085376739502
# Epoch:  2 Batch:  150 Current Loss:  0.37908387184143066
# Epoch:  2 Batch:  200 Current Loss:  0.14523077011108398
# Epoch:  2 Batch:  250 Current Loss:  0.23160696029663086
# Epoch:  2 Batch:  300 Current Loss:  0.1410256326198578
# Epoch:  2 Batch:  350 Current Loss:  0.13326768577098846
# ================================================================================
# Epoch 2 completed
# Average train loss is 0.2196810577623546:
# Average validation loss is 0.1629758246988058
# ================================================================================
# Epoch:  3 Batch:  0 Current Loss:  0.2686358690261841
# Epoch:  3 Batch:  50 Current Loss:  0.23856958746910095
# Epoch:  3 Batch:  100 Current Loss:  0.08563397079706192
# Epoch:  3 Batch:  150 Current Loss:  0.26260507106781006
# Epoch:  3 Batch:  200 Current Loss:  0.08872190862894058
# Epoch:  3 Batch:  250 Current Loss:  0.1854933500289917
# Epoch:  3 Batch:  300 Current Loss:  0.10465820878744125
# Epoch:  3 Batch:  350 Current Loss:  0.08115015923976898
# ================================================================================
# Epoch 3 completed
# Average train loss is 0.1628201641328633:
# Average validation loss is 0.1087536308914423
# ================================================================================
# Epoch:  4 Batch:  0 Current Loss:  0.20790767669677734
# Epoch:  4 Batch:  50 Current Loss:  0.16412079334259033
# Epoch:  4 Batch:  100 Current Loss:  0.0565149150788784
# Epoch:  4 Batch:  150 Current Loss:  0.20506665110588074
# Epoch:  4 Batch:  200 Current Loss:  0.0909370481967926
# Epoch:  4 Batch:  250 Current Loss:  0.11550448089838028
# Epoch:  4 Batch:  300 Current Loss:  0.06728096306324005
# Epoch:  4 Batch:  350 Current Loss:  0.0641167163848877
# ================================================================================
# Epoch 4 completed
# Average train loss is 0.12177440376020968:
# Average validation loss is 0.10880430735647678
# ================================================================================
# Epoch:  5 Batch:  0 Current Loss:  0.18376322090625763
# Epoch:  5 Batch:  50 Current Loss:  0.12941017746925354
# Epoch:  5 Batch:  100 Current Loss:  0.04587404802441597
# Epoch:  5 Batch:  150 Current Loss:  0.15129399299621582
# Epoch:  5 Batch:  200 Current Loss:  0.04490020498633385
# Epoch:  5 Batch:  250 Current Loss:  0.1049685925245285
# Epoch:  5 Batch:  300 Current Loss:  0.04888896271586418
# Epoch:  5 Batch:  350 Current Loss:  0.06550171971321106
# ================================================================================
# Epoch 5 completed
# Average train loss is 0.10442706428468228:
# Average validation loss is 0.09172540556639433
# ================================================================================
# Epoch:  6 Batch:  0 Current Loss:  0.15686234831809998
# Epoch:  6 Batch:  50 Current Loss:  0.08192523568868637
# Epoch:  6 Batch:  100 Current Loss:  0.03615890443325043
# Epoch:  6 Batch:  150 Current Loss:  0.17455853521823883
# Epoch:  6 Batch:  200 Current Loss:  0.0404600128531456
# Epoch:  6 Batch:  250 Current Loss:  0.08874126523733139
# Epoch:  6 Batch:  300 Current Loss:  0.05809357762336731
# Epoch:  6 Batch:  350 Current Loss:  0.06303206831216812
# ================================================================================
# Epoch 6 completed
# Average train loss is 0.09389082061126829:
# Average validation loss is 0.1009050004556775
# ================================================================================
# Epoch:  7 Batch:  0 Current Loss:  0.19365927577018738
# Epoch:  7 Batch:  50 Current Loss:  0.11310316622257233
# Epoch:  7 Batch:  100 Current Loss:  0.04970335215330124
# Epoch:  7 Batch:  150 Current Loss:  0.10049368441104889
# Epoch:  7 Batch:  200 Current Loss:  0.04214799404144287
# Epoch:  7 Batch:  250 Current Loss:  0.09833789616823196
# Epoch:  7 Batch:  300 Current Loss:  0.04983175918459892
# Epoch:  7 Batch:  350 Current Loss:  0.05298919603228569
# ================================================================================
# Epoch 7 completed
# Average train loss is 0.0862859671190381:
# Average validation loss is 0.0843474924378097
# ================================================================================
# Epoch:  8 Batch:  0 Current Loss:  0.1320212185382843
# Epoch:  8 Batch:  50 Current Loss:  0.07992628216743469
# Epoch:  8 Batch:  100 Current Loss:  0.04008599370718002
# Epoch:  8 Batch:  150 Current Loss:  0.24613124132156372
# Epoch:  8 Batch:  200 Current Loss:  0.04079592972993851
# Epoch:  8 Batch:  250 Current Loss:  0.10232041031122208
# Epoch:  8 Batch:  300 Current Loss:  0.05083933100104332
# Epoch:  8 Batch:  350 Current Loss:  0.09351006150245667
# ================================================================================
# Epoch 8 completed
# Average train loss is 0.08576522401999682:
# Average validation loss is 0.08619496669620276
# ================================================================================
# Epoch:  9 Batch:  0 Current Loss:  0.10668390989303589
# Epoch:  9 Batch:  50 Current Loss:  0.06577044725418091
# Epoch:  9 Batch:  100 Current Loss:  0.032319992780685425
# Epoch:  9 Batch:  150 Current Loss:  0.10419546812772751
# Epoch:  9 Batch:  200 Current Loss:  0.03808600455522537
# Epoch:  9 Batch:  250 Current Loss:  0.08943337947130203
# Epoch:  9 Batch:  300 Current Loss:  0.05601812154054642
# Epoch:  9 Batch:  350 Current Loss:  0.09586750715970993
# ================================================================================
# Epoch 9 completed
# Average train loss is 0.07971457339357585:
# Average validation loss is 0.09980493180453777
# ================================================================================
# Epoch:  10 Batch:  0 Current Loss:  0.10327814519405365
# Epoch:  10 Batch:  50 Current Loss:  0.0677497610449791
# Epoch:  10 Batch:  100 Current Loss:  0.031050963327288628
# Epoch:  10 Batch:  150 Current Loss:  0.09100145846605301
# Epoch:  10 Batch:  200 Current Loss:  0.039239272475242615
# Epoch:  10 Batch:  250 Current Loss:  0.07855424284934998
# Epoch:  10 Batch:  300 Current Loss:  0.060761768370866776
# Epoch:  10 Batch:  350 Current Loss:  0.06589899957180023
# ================================================================================
# Epoch 10 completed
# Average train loss is 0.07791233690455555:
# Average validation loss is 0.09985614307224751
# ================================================================================
# Epoch:  11 Batch:  0 Current Loss:  0.12161192297935486
# Epoch:  11 Batch:  50 Current Loss:  0.06658761948347092
# Epoch:  11 Batch:  100 Current Loss:  0.03021412342786789
# Epoch:  11 Batch:  150 Current Loss:  0.11384408175945282
# Epoch:  11 Batch:  200 Current Loss:  0.04372221603989601
# Epoch:  11 Batch:  250 Current Loss:  0.09086047112941742
# Epoch:  11 Batch:  300 Current Loss:  0.047335896641016006
# Epoch:  11 Batch:  350 Current Loss:  0.06072697415947914
# ================================================================================
# Epoch 11 completed
# Average train loss is 0.07397518123500049:
# Average validation loss is 0.08221061980351806
# ================================================================================
# Epoch:  12 Batch:  0 Current Loss:  0.11405152082443237
# Epoch:  12 Batch:  50 Current Loss:  0.08888782560825348
# Epoch:  12 Batch:  100 Current Loss:  0.03090466558933258
# Epoch:  12 Batch:  150 Current Loss:  0.14727580547332764
# Epoch:  12 Batch:  200 Current Loss:  0.04498247802257538
# Epoch:  12 Batch:  250 Current Loss:  0.09166416525840759
# Epoch:  12 Batch:  300 Current Loss:  0.058626215904951096
# Epoch:  12 Batch:  350 Current Loss:  0.054936978965997696
# ================================================================================
# Epoch 12 completed
# Average train loss is 0.07286706156563014:
# Average validation loss is 0.09801721889525652
# ================================================================================
# Epoch:  13 Batch:  0 Current Loss:  0.13509078323841095
# Epoch:  13 Batch:  50 Current Loss:  0.10033158957958221
# Epoch:  13 Batch:  100 Current Loss:  0.03439243137836456
# Epoch:  13 Batch:  150 Current Loss:  0.1153562068939209
# Epoch:  13 Batch:  200 Current Loss:  0.040074434131383896
# Epoch:  13 Batch:  250 Current Loss:  0.08442524820566177
# Epoch:  13 Batch:  300 Current Loss:  0.03568305820226669
# Epoch:  13 Batch:  350 Current Loss:  0.05678839236497879
# ================================================================================
# Epoch 13 completed
# Average train loss is 0.07225532432552427:
# Average validation loss is 0.07827354269102216
# ================================================================================
# Epoch:  14 Batch:  0 Current Loss:  0.08119191974401474
# Epoch:  14 Batch:  50 Current Loss:  0.06388536095619202
# Epoch:  14 Batch:  100 Current Loss:  0.0267043374478817
# Epoch:  14 Batch:  150 Current Loss:  0.05601249635219574
# Epoch:  14 Batch:  200 Current Loss:  0.04098068177700043
# Epoch:  14 Batch:  250 Current Loss:  0.09621114283800125
# Epoch:  14 Batch:  300 Current Loss:  0.0529060959815979
# Epoch:  14 Batch:  350 Current Loss:  0.059413764625787735
# ================================================================================
# Epoch 14 completed
# Average train loss is 0.06652816826943309:
# Average validation loss is 0.06395368637517095
# ================================================================================
# Epoch:  15 Batch:  0 Current Loss:  0.11487466096878052
# Epoch:  15 Batch:  50 Current Loss:  0.08739134669303894
# Epoch:  15 Batch:  100 Current Loss:  0.026698540896177292
# Epoch:  15 Batch:  150 Current Loss:  0.11819028854370117
# Epoch:  15 Batch:  200 Current Loss:  0.04179341718554497
# Epoch:  15 Batch:  250 Current Loss:  0.08596508204936981
# Epoch:  15 Batch:  300 Current Loss:  0.05000963807106018
# Epoch:  15 Batch:  350 Current Loss:  0.08666565269231796
# ================================================================================
# Epoch 15 completed
# Average train loss is 0.06833650753833354:
# Average validation loss is 0.07947601841762662
# ================================================================================
# Epoch:  16 Batch:  0 Current Loss:  0.1226019337773323
# Epoch:  16 Batch:  50 Current Loss:  0.060833461582660675
# Epoch:  16 Batch:  100 Current Loss:  0.03886168450117111
# Epoch:  16 Batch:  150 Current Loss:  0.07844053208827972
# Epoch:  16 Batch:  200 Current Loss:  0.03759445250034332
# Epoch:  16 Batch:  250 Current Loss:  0.10788130760192871
# Epoch:  16 Batch:  300 Current Loss:  0.08843734860420227
# Epoch:  16 Batch:  350 Current Loss:  0.06641785800457001
# ================================================================================
# Epoch 16 completed
# Average train loss is 0.0661989361885935:
# Average validation loss is 0.06286567337810993
# ================================================================================
# Epoch:  17 Batch:  0 Current Loss:  0.07780034840106964
# Epoch:  17 Batch:  50 Current Loss:  0.05600930005311966
# Epoch:  17 Batch:  100 Current Loss:  0.027318540960550308
# Epoch:  17 Batch:  150 Current Loss:  0.21536897122859955
# Epoch:  17 Batch:  200 Current Loss:  0.04353495314717293
# Epoch:  17 Batch:  250 Current Loss:  0.0704539492726326
# Epoch:  17 Batch:  300 Current Loss:  0.041115231812000275
# Epoch:  17 Batch:  350 Current Loss:  0.10969526320695877
# ================================================================================
# Epoch 17 completed
# Average train loss is 0.0638195982715115:
# Average validation loss is 0.06612039152532816
# ================================================================================
# Epoch:  18 Batch:  0 Current Loss:  0.08155324310064316
# Epoch:  18 Batch:  50 Current Loss:  0.04628990963101387
# Epoch:  18 Batch:  100 Current Loss:  0.026878798380494118
# Epoch:  18 Batch:  150 Current Loss:  0.07592472434043884
# Epoch:  18 Batch:  200 Current Loss:  0.03796502575278282
# Epoch:  18 Batch:  250 Current Loss:  0.0752507746219635
# Epoch:  18 Batch:  300 Current Loss:  0.04443107545375824
# Epoch:  18 Batch:  350 Current Loss:  0.0637224018573761
# ================================================================================
# Epoch 18 completed
# Average train loss is 0.059994298596866426:
# Average validation loss is 0.0671336186490953
# ================================================================================
# Epoch:  19 Batch:  0 Current Loss:  0.06366215646266937
# Epoch:  19 Batch:  50 Current Loss:  0.04320244863629341
# Epoch:  19 Batch:  100 Current Loss:  0.022542953491210938
# Epoch:  19 Batch:  150 Current Loss:  0.12155663967132568
# Epoch:  19 Batch:  200 Current Loss:  0.03896866366267204
# Epoch:  19 Batch:  250 Current Loss:  0.08186112344264984
# Epoch:  19 Batch:  300 Current Loss:  0.035124294459819794
# Epoch:  19 Batch:  350 Current Loss:  0.0738152489066124
# ================================================================================
# Epoch 19 completed
# Average train loss is 0.06094849755521864:
# Average validation loss is 0.06438284764066339
# ================================================================================
# Epoch:  20 Batch:  0 Current Loss:  0.06400257349014282
# Epoch:  20 Batch:  50 Current Loss:  0.06080375611782074
# Epoch:  20 Batch:  100 Current Loss:  0.026159025728702545
# Epoch:  20 Batch:  150 Current Loss:  0.05087192729115486
# Epoch:  20 Batch:  200 Current Loss:  0.0343068465590477
# Epoch:  20 Batch:  250 Current Loss:  0.07715854793787003
# Epoch:  20 Batch:  300 Current Loss:  0.058615490794181824
# Epoch:  20 Batch:  350 Current Loss:  0.06191463768482208
# ================================================================================
# Epoch 20 completed
# Average train loss is 0.05945912781637162:
# Average validation loss is 0.0744778798893094
# ================================================================================

# %%
plt.plot(train_running_loss_history, label = 'Train Loss')
plt.plot(validation_running_loss_history, label = 'Validation Loss')
plt.legend()

# %%
model.eval()
X_train.size()
# Out:
# torch.Size([1, 1, 572, 572])

# %%
torch.save(model, 'savedmodel/UNet++1.pt')

# %%
model = torch.load(os.path.join(parent_folder, 'savedmodel/UNet++.pt'))
model.to('cuda')
model.eval()
# Out:
# UNet_2Plus(
#   (conv00): unetConv2(
#     (conv1): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (maxpool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv10): unetConv2(
#     (conv1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv20): unetConv2(
#     (conv1): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv30): unetConv2(
#     (conv1): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv40): unetConv2(
#     (conv1): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (up_concat01): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat11): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat21): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat31): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat02): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat12): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat22): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat03): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat13): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (up_concat04): unetUp_origin(
#     (conv): unetConv2(
#       (conv1): Sequential(
#         (0): Conv2d(320, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (final_1): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   (final_2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   (final_3): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   (final_4): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
def avg_dice_index(dataloader):
    dice = 0.0
    model.eval()
    with torch.no_grad():
        for ith_batch, sample_batched in enumerate(dataloader):
            X_train = sample_batched['image'].to('cuda')
            y_train = sample_batched['annotation'].to('cuda')
            y_predict = (model(X_train) + 0.5).int().float()
            dice += dice_index(y_predict, y_train)
    avg_dice = dice / len(dataloader)
    return avg_dice.item()

# %%
avg_dice_index(validation_loader)    #### Dice index of validation data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4385aae7cd5b> in <module>
# ----> 1 avg_dice_index(validation_loader)    #### Dice index of validation data
#
# NameError: name 'avg_dice_index' is not defined

# %%
avg_dice_index(train_loader)    #### Dice index of validation data
# Out:
# 0.9438002705574036

# %%
class HC18_test(Dataset):
    def __init__(self, transformX = None):
        self.pixel_file = pd.read_csv(os.path.join(data_folder, 'test_set_pixel_size.csv'))
        self.transformX = transformX
        
    def __len__(self):
        return len(self.pixel_file)
    
    def __getitem__(self, index):
        imx_name = os.path.join(data_folder,'test_set_A', self.pixel_file.iloc[index, 0])
        
        imx = Image.open(imx_name)
        
        f_name = self.pixel_file.iloc[index, 0]
        
        if self.transformX :
            imx = self.transformX(imx)
        
        sample = {'image': imx, 'f_name': f_name}
        return sample
tx_X = transforms.Compose([transforms.Resize((572, 572)),
                           transforms.ToTensor(),
                           transforms.Normalize((0.5,), (0.5,))])
test_data = HC18_test(transformX = tx_X)
test_loader = DataLoader(dataset = test_data, batch_size = 2, shuffle = True)

# %%
# The following functions will return numpy array from the transformed tensors which were
# obtained from our train_loader. Plot them and see if they are intact
def im_converterX(tensor):
  image = tensor.cpu().clone().detach().numpy() # make copy of tensor and converting it to numpy 
                                              # as we will need original later
  image = image.transpose(1,2,0) # swapping axes making (1, 28, 28) image to a (28, 28, 1)
  # print(image.shape)
  image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5)) # unnormalizing the image 
                                              # this also outputs (28, 28, 3) which seems important for plt.imshow
  image = image.clip(0, 1) # to make sure final values are in range 0 to 1 as .ToTensor outputed
  return image

def im_converterY(tensor):
  image = tensor.cpu().clone().detach().numpy() 
  image = image.transpose(1,2,0) 
  # print(image.shape)
  image = image * np.array((1, 1, 1)) 
  image = image.clip(0, 1) 
  return image

# %%
## Here we loop through our train_loader and see the images
## Looks good
fig = plt.figure(figsize = (15,6))
#model.to('cpu')
for ith_batch, sample_batched in enumerate(test_loader):
  
    X_test = sample_batched['image'].to('cuda')
    print(ith_batch, X_test.size())
    
    y_test = (model(X_test) + 0.5).int().float()
    
    
    
    for index in range(2):
        ax = fig.add_subplot(2, 2 , index + 1)  # subplot index starts from 1
        plt.imshow(im_converterX(X_test[index]))
        
        ax  = fig.add_subplot(2, 2, index + 3)
        plt.imshow(im_converterY(y_test[index]))
    break
# Out:
# 0 torch.Size([2, 1, 572, 572])
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((540, 800)),
        transforms.ToTensor()
        ])
    
with torch.no_grad():
      model.eval()
      for ith_batch , sample in enumerate(test_loader):
        X_test = sample['image'].to('cuda')
        y_pred = (model(X_test) + 0.5).int().float().cpu()
       # print(335-ith_batch)
        
        file_names = sample['f_name']
        singh = transform(y_pred[0])
        torchvision.utils.save_image(singh, os.path.join(data_folder,'test_set_C', file_names[0]))
      print("Segmentation files written")
# Out:
# Segmentation files written

# %%
def fit_ellipse(im):    
    imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(imgray,127,255,0)
    contours, _ = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contour_sizes = [len(contour) for contour in contours]
    ellipse = cv2.fitEllipse(contours[np.argmax(contour_sizes)])
    return ellipse

# %%
#!unzip test_set.zip
# Out:
# Archive:  test_set.zip
#    creating: test_set/
#   inflating: test_set/000_HC.png
#  extracting: test_set/001_HC.png
#  extracting: test_set/002_HC.png
#  extracting: test_set/003_HC.png
#  extracting: test_set/004_HC.png
#  extracting: test_set/005_HC.png
#  extracting: test_set/006_HC.png
#  extracting: test_set/007_HC.png
#  extracting: test_set/008_HC.png
#   inflating: test_set/009_HC.png
#  extracting: test_set/010_HC.png
#  extracting: test_set/011_HC.png
#   inflating: test_set/012_HC.png
#  extracting: test_set/013_HC.png
#  extracting: test_set/014_HC.png
#   inflating: test_set/015_HC.png
#  extracting: test_set/016_HC.png
#  extracting: test_set/017_HC.png
#  extracting: test_set/018_HC.png
#  extracting: test_set/019_HC.png
#  extracting: test_set/020_HC.png
#  extracting: test_set/021_HC.png
#  extracting: test_set/022_HC.png
#  extracting: test_set/023_HC.png
#  extracting: test_set/024_HC.png
#  extracting: test_set/025_HC.png
#  extracting: test_set/026_HC.png
#  extracting: test_set/027_HC.png
#  extracting: test_set/028_HC.png
#  extracting: test_set/029_HC.png
#  extracting: test_set/030_HC.png
#  extracting: test_set/031_HC.png
#  extracting: test_set/032_HC.png
#  extracting: test_set/033_HC.png
#  extracting: test_set/034_HC.png
#  extracting: test_set/035_HC.png
#  extracting: test_set/036_HC.png
#  extracting: test_set/037_HC.png
#  extracting: test_set/038_HC.png
#  extracting: test_set/039_HC.png
#  extracting: test_set/040_HC.png
#  extracting: test_set/041_HC.png
#  extracting: test_set/042_HC.png
#  extracting: test_set/043_HC.png
#  extracting: test_set/044_HC.png
#  extracting: test_set/045_HC.png
#  extracting: test_set/046_HC.png
#  extracting: test_set/047_HC.png
#   inflating: test_set/048_HC.png
#  extracting: test_set/049_HC.png
#  extracting: test_set/050_HC.png
#  extracting: test_set/051_HC.png
#  extracting: test_set/052_HC.png
#  extracting: test_set/053_HC.png
#  extracting: test_set/054_HC.png
#  extracting: test_set/055_HC.png
#  extracting: test_set/056_HC.png
#  extracting: test_set/057_HC.png
#  extracting: test_set/058_HC.png
#  extracting: test_set/059_HC.png
#  extracting: test_set/060_HC.png
#  extracting: test_set/061_HC.png
#  extracting: test_set/062_HC.png
#  extracting: test_set/063_HC.png
#  extracting: test_set/064_HC.png
#  extracting: test_set/065_HC.png
#  extracting: test_set/066_HC.png
#  extracting: test_set/067_HC.png
#   inflating: test_set/068_HC.png
#  extracting: test_set/069_HC.png
#  extracting: test_set/070_HC.png
#  extracting: test_set/071_HC.png
#  extracting: test_set/072_HC.png
#  extracting: test_set/073_HC.png
#  extracting: test_set/074_HC.png
#  extracting: test_set/075_HC.png
#  extracting: test_set/076_HC.png
#  extracting: test_set/077_HC.png
#  extracting: test_set/078_HC.png
#  extracting: test_set/079_HC.png
#  extracting: test_set/080_HC.png
#  extracting: test_set/081_HC.png
#  extracting: test_set/082_HC.png
#  extracting: test_set/083_HC.png
#  extracting: test_set/084_HC.png
#  extracting: test_set/085_HC.png
#  extracting: test_set/086_HC.png
#  extracting: test_set/087_HC.png
#   inflating: test_set/088_HC.png
#  extracting: test_set/089_HC.png
#  extracting: test_set/090_HC.png
#  extracting: test_set/091_HC.png
#  extracting: test_set/092_HC.png
#  extracting: test_set/093_HC.png
#  extracting: test_set/094_HC.png
#  extracting: test_set/095_HC.png
#  extracting: test_set/096_HC.png
#  extracting: test_set/097_HC.png
#  extracting: test_set/098_HC.png
#  extracting: test_set/099_HC.png
#  extracting: test_set/100_HC.png
#  extracting: test_set/101_HC.png
#  extracting: test_set/102_HC.png
#  extracting: test_set/103_HC.png
#  extracting: test_set/104_HC.png
#   inflating: test_set/105_HC.png
#  extracting: test_set/106_HC.png
#  extracting: test_set/107_HC.png
#  extracting: test_set/108_HC.png
#  extracting: test_set/109_HC.png
#  extracting: test_set/110_HC.png
#  extracting: test_set/111_HC.png
#  extracting: test_set/112_HC.png
#  extracting: test_set/113_HC.png
#  extracting: test_set/114_HC.png
#  extracting: test_set/115_HC.png
#  extracting: test_set/116_HC.png
#  extracting: test_set/117_HC.png
#  extracting: test_set/118_HC.png
#  extracting: test_set/119_HC.png
#  extracting: test_set/120_HC.png
#  extracting: test_set/121_HC.png
#  extracting: test_set/122_HC.png
#  extracting: test_set/123_HC.png
#  extracting: test_set/124_HC.png
#  extracting: test_set/125_HC.png
#  extracting: test_set/126_HC.png
#  extracting: test_set/127_HC.png
#  extracting: test_set/128_HC.png
#  extracting: test_set/129_HC.png
#  extracting: test_set/130_HC.png
#  extracting: test_set/131_HC.png
#  extracting: test_set/132_HC.png
#  extracting: test_set/133_HC.png
#   inflating: test_set/134_HC.png
#  extracting: test_set/135_HC.png
#  extracting: test_set/136_HC.png
#  extracting: test_set/137_HC.png
#  extracting: test_set/138_HC.png
#  extracting: test_set/139_HC.png
#  extracting: test_set/140_HC.png
#  extracting: test_set/141_HC.png
#  extracting: test_set/142_HC.png
#  extracting: test_set/143_HC.png
#  extracting: test_set/144_HC.png
#  extracting: test_set/145_HC.png
#  extracting: test_set/146_HC.png
#  extracting: test_set/147_HC.png
#  extracting: test_set/148_HC.png
#  extracting: test_set/149_HC.png
#  extracting: test_set/150_HC.png
#  extracting: test_set/151_HC.png
#  extracting: test_set/152_HC.png
#  extracting: test_set/153_HC.png
#  extracting: test_set/154_HC.png
#  extracting: test_set/155_HC.png
#  extracting: test_set/156_HC.png
#  extracting: test_set/157_HC.png
#  extracting: test_set/158_HC.png
#  extracting: test_set/159_HC.png
#  extracting: test_set/160_HC.png
#  extracting: test_set/161_HC.png
#  extracting: test_set/162_HC.png
#  extracting: test_set/163_HC.png
#  extracting: test_set/164_HC.png
#  extracting: test_set/165_HC.png
#  extracting: test_set/166_HC.png
#  extracting: test_set/167_HC.png
#  extracting: test_set/168_HC.png
#  extracting: test_set/169_HC.png
#  extracting: test_set/170_HC.png
#  extracting: test_set/171_HC.png
#  extracting: test_set/172_HC.png
#  extracting: test_set/173_HC.png
#  extracting: test_set/174_HC.png
#  extracting: test_set/175_HC.png
#  extracting: test_set/176_HC.png
#  extracting: test_set/177_HC.png
#  extracting: test_set/178_HC.png
#  extracting: test_set/179_HC.png
#  extracting: test_set/180_HC.png
#  extracting: test_set/181_HC.png
#  extracting: test_set/182_HC.png
#  extracting: test_set/183_HC.png
#  extracting: test_set/184_HC.png
#  extracting: test_set/185_HC.png
#  extracting: test_set/186_HC.png
#  extracting: test_set/187_HC.png
#  extracting: test_set/188_HC.png
#  extracting: test_set/189_HC.png
#  extracting: test_set/190_HC.png
#  extracting: test_set/191_HC.png
#  extracting: test_set/192_HC.png
#  extracting: test_set/193_HC.png
#  extracting: test_set/194_HC.png
#  extracting: test_set/195_HC.png
#  extracting: test_set/196_HC.png
#  extracting: test_set/197_HC.png
#   inflating: test_set/198_HC.png
#  extracting: test_set/199_HC.png
#  extracting: test_set/200_HC.png
#  extracting: test_set/201_HC.png
#   inflating: test_set/202_HC.png
#   inflating: test_set/203_HC.png
#  extracting: test_set/204_HC.png
#  extracting: test_set/205_HC.png
#  extracting: test_set/206_HC.png
#  extracting: test_set/207_HC.png
#  extracting: test_set/208_HC.png
#  extracting: test_set/209_HC.png
#  extracting: test_set/210_HC.png
#  extracting: test_set/211_HC.png
#  extracting: test_set/212_HC.png
#  extracting: test_set/213_HC.png
#  extracting: test_set/214_HC.png
#  extracting: test_set/215_HC.png
#  extracting: test_set/216_HC.png
#  extracting: test_set/217_HC.png
#  extracting: test_set/218_HC.png
#  extracting: test_set/219_HC.png
#  extracting: test_set/220_HC.png
#  extracting: test_set/221_HC.png
#  extracting: test_set/222_HC.png
#  extracting: test_set/223_HC.png
#  extracting: test_set/224_HC.png
#  extracting: test_set/225_HC.png
#  extracting: test_set/226_HC.png
#  extracting: test_set/227_HC.png
#  extracting: test_set/228_HC.png
#  extracting: test_set/229_HC.png
#  extracting: test_set/230_HC.png
#  extracting: test_set/231_HC.png
#  extracting: test_set/232_HC.png
#  extracting: test_set/233_HC.png
#  extracting: test_set/234_HC.png
#  extracting: test_set/235_HC.png
#  extracting: test_set/236_HC.png
#  extracting: test_set/237_HC.png
#  extracting: test_set/238_HC.png
#  extracting: test_set/239_HC.png
#  extracting: test_set/240_HC.png
#   inflating: test_set/241_HC.png
#  extracting: test_set/242_HC.png
#  extracting: test_set/243_HC.png
#  extracting: test_set/244_HC.png
#  extracting: test_set/245_HC.png
#  extracting: test_set/246_HC.png
#   inflating: test_set/247_HC.png
#  extracting: test_set/248_HC.png
#   inflating: test_set/249_HC.png
#  extracting: test_set/250_HC.png
#  extracting: test_set/251_HC.png
#  extracting: test_set/252_HC.png
#  extracting: test_set/253_HC.png
#  extracting: test_set/254_HC.png
#  extracting: test_set/255_HC.png
#  extracting: test_set/256_HC.png
#  extracting: test_set/257_HC.png
#  extracting: test_set/258_HC.png
#  extracting: test_set/259_HC.png
#  extracting: test_set/260_HC.png
#  extracting: test_set/261_HC.png
#  extracting: test_set/262_HC.png
#   inflating: test_set/263_HC.png
#   inflating: test_set/264_HC.png
#   inflating: test_set/265_HC.png
#  extracting: test_set/266_HC.png
#  extracting: test_set/267_HC.png
#  extracting: test_set/268_HC.png
#  extracting: test_set/269_HC.png
#  extracting: test_set/270_HC.png
#  extracting: test_set/271_HC.png
#  extracting: test_set/272_HC.png
#  extracting: test_set/273_HC.png
#  extracting: test_set/274_HC.png
#  extracting: test_set/275_HC.png
#  extracting: test_set/276_HC.png
#  extracting: test_set/277_HC.png
#   inflating: test_set/278_HC.png
#  extracting: test_set/279_HC.png
#   inflating: test_set/280_HC.png
#  extracting: test_set/281_HC.png
#  extracting: test_set/282_HC.png
#  extracting: test_set/283_HC.png
#  extracting: test_set/284_HC.png
#  extracting: test_set/285_HC.png
#  extracting: test_set/286_HC.png
#  extracting: test_set/287_HC.png
#  extracting: test_set/288_HC.png
#  extracting: test_set/289_HC.png
#   inflating: test_set/290_HC.png
#   inflating: test_set/291_HC.png
#  extracting: test_set/292_HC.png
#  extracting: test_set/293_HC.png
#  extracting: test_set/294_HC.png
#  extracting: test_set/295_HC.png
#  extracting: test_set/296_HC.png
#  extracting: test_set/297_HC.png
#  extracting: test_set/298_HC.png
#  extracting: test_set/299_HC.png
#  extracting: test_set/300_HC.png
#  extracting: test_set/301_HC.png
#  extracting: test_set/302_HC.png
#  extracting: test_set/303_HC.png
#  extracting: test_set/304_HC.png
#  extracting: test_set/305_HC.png
#  extracting: test_set/306_HC.png
#  extracting: test_set/307_HC.png
#  extracting: test_set/308_HC.png
#  extracting: test_set/309_HC.png
#  extracting: test_set/310_HC.png
#  extracting: test_set/311_HC.png
#  extracting: test_set/312_HC.png
#  extracting: test_set/313_HC.png
#  extracting: test_set/314_HC.png
#   inflating: test_set/315_HC.png
#  extracting: test_set/316_HC.png
#  extracting: test_set/317_HC.png
#  extracting: test_set/318_HC.png
#  extracting: test_set/319_HC.png
#  extracting: test_set/320_HC.png
#  extracting: test_set/321_HC.png
#  extracting: test_set/322_HC.png
#  extracting: test_set/323_HC.png
#  extracting: test_set/324_HC.png
#  extracting: test_set/325_HC.png
#  extracting: test_set/326_HC.png
#  extracting: test_set/327_HC.png
#  extracting: test_set/328_HC.png
#  extracting: test_set/329_HC.png
#  extracting: test_set/330_HC.png
#  extracting: test_set/331_HC.png
#  extracting: test_set/332_HC.png
#  extracting: test_set/333_HC.png
#  extracting: test_set/334_HC.png

# %%
df_pixel_size = pd.read_csv(os.path.join(data_folder, 'test_set_pixel_size.csv'))
submission = {'filename': [], 'center_x_mm': [], 'center_y_mm': [], 'semi_axes_a_mm': [],
             'semi_axes_b_mm': [], 'angle_rad': [], 'Index': []}

file_names = sorted([file for _,_,files in os.walk('test_set') for file in files])

for i, file_name in enumerate(file_names):
    im = cv2.imread('test_set/'+file_name)
   # file_name = file_name.replace('_Segmented', '')
    ellipse = fit_ellipse(im)
    im_mask = cv2.ellipse(np.zeros_like(im),ellipse,(255,255,255),-1)
    image_name = file_name.split('.')[0] + '_Annotation_fit.png'
    #cv2.imwrite('/content/drive/My Drive/HC18/test_set/'+image_name, im_mask)
    
    pixel_size = df_pixel_size.loc[df_pixel_size['filename'] == file_name, 'pixel size(mm)'].iloc[0]
    submission['filename'].extend([file_name])
    submission['Index'].extend([int(file_name.split('_')[0])])
    center_x,  center_y = ellipse[0]
    submission['center_x_mm'].extend([pixel_size*center_x])
    submission['center_y_mm'].extend([pixel_size*center_y])
    semi_axes_b, semi_axes_a = ellipse[1]
    if semi_axes_b > semi_axes_a:
        semi_axes_b = semi_axes_b + semi_axes_a
        semi_axes_a = semi_axes_b - semi_axes_a
        semi_axes_b -= semi_axes_a
    submission['semi_axes_a_mm'].extend([semi_axes_a*pixel_size/2])
    submission['semi_axes_b_mm'].extend([semi_axes_b*pixel_size/2])
    angle = ellipse[2]
    if angle < 90:
        angle += 90
    else:
        angle -= 90
    submission['angle_rad'].extend([np.deg2rad(angle)])
    
submission = pd.DataFrame(submission)
submission = submission[['filename', 'center_x_mm', 'center_y_mm', 
                         'semi_axes_a_mm', 'semi_axes_b_mm', 'angle_rad', 'Index']]    
submission = submission.sort_values(['Index'])
submission = submission.drop('Index', axis=1)
submission.to_csv("seventh_submit_data_aug.csv", index=False)
print('Required .csv file generated')
# Out:
# Required .csv file generated

# %%
q = pd.read_csv('seventh_submit_data_aug.csv')  ## to check theck the generated csv

# %%
print('Length of csv file: ', len(q))
# Out:
# Length of csv file:  0
